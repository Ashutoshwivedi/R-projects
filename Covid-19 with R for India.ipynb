# %%
#importing libraries
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#loading data
data = pd.read_csv('../input/covid-data-india-statewise/COVID_19 INDIA - Sheet1.csv')
data
# Out:
#                                     State/UT  Confirmed Cases  Active Cases  \
# 0                Andaman and Nicobar Islands            10031             1
# 1                             Andhra Pradesh          2319328           450
# 2                          Arunachal Pradesh            64484             2
# 3                                      Assam           724193          1364
# 4                                      Bihar           830435            35
# 5                                 Chandigarh            91894            21
# 6                               Chhattisgarh          1151995           132
# 7   Dadra and Nagar Haveli and Daman and Diu            11441             0
# 8                                      Delhi          1864135           490
# 9                                        Goa           245265            50
# 10                                   Gujarat          1223806           299
# ...

# %%
#2 Understanding the data

# %%
#to obtain no of rows and columns
data.shape
# Out:
# (36, 5)

# %%
data.columns #returns names of columns
# Out:
# Index(['State/UT', 'Confirmed Cases', 'Active Cases', 'Cured/Discharged',
#        'Death'],
#       dtype='object')

# %%
data.info() #gives concise summary of dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State/UT          36 non-null     object
#  1   Confirmed Cases   36 non-null     int64
#  2   Active Cases      36 non-null     int64
#  3   Cured/Discharged  36 non-null     int64
#  4   Death             36 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 1.5+ KB

# %%
data.nunique() #returns no of unique values in each column
# Out:
# State/UT            36
# Confirmed Cases     36
# Active Cases        33
# Cured/Discharged    36
# Death               36
# dtype: int64

# %%
#statistical summary
data.describe()
# Out:
#        Confirmed Cases  Active Cases  Cured/Discharged          Death
# count     3.600000e+01     36.000000      3.600000e+01      36.000000
# mean      1.194852e+06    622.972222      1.179877e+06   14352.000000
# std       1.767652e+06   1281.877362      1.741698e+06   26272.738096
# min       1.003100e+04      0.000000      9.901000e+03       4.000000
# 25%       9.908775e+04     30.500000      9.798725e+04    1103.500000
# 50%       5.888940e+05    139.500000      5.824615e+05    5977.000000
# 75%       1.283880e+06    526.750000      1.274074e+06   14208.000000
# max       7.872817e+06   5918.000000      7.723959e+06  143769.000000

# %%
#2 cleaning the data

# %%
#to check whether null values are present
data.isnull().sum()
# Out:
# State/UT            0
# Confirmed Cases     0
# Active Cases        0
# Cured/Discharged    0
# Death               0
# dtype: int64

# %%
#3 Relationship analysis

# %%
correlation = data.corr()
correlation
# Out:
#                   Confirmed Cases  Active Cases  Cured/Discharged     Death
# Confirmed Cases          1.000000      0.887896          0.999988  0.945352
# Active Cases             0.887896      1.000000          0.887648  0.844769
# Cured/Discharged         0.999988      0.887648          1.000000  0.943732
# Death                    0.945352      0.844769          0.943732  1.000000

# %%
#plotting the correlation
sns.heatmap(correlation, xticklabels = correlation.columns, yticklabels = correlation.columns, annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data)

# %%
sns.pairplot(data, kind = 'hist')

# %%
#sorting data in ascending order
data.sort_values (['Confirmed Cases'], inplace=True, ascending=False)
data
# Out:
#                                     State/UT  Confirmed Cases  Active Cases  \
# 20                               Maharashtra          7872817          5089
# 16                                    Kerala          6529049          5918
# 15                                 Karnataka          3944970          1844
# 30                                Tamil Nadu          3452534           505
# 1                             Andhra Pradesh          2319328           450
# 33                             Uttar Pradesh          2070441           700
# 35                               West Bengal          2016976           805
# 8                                      Delhi          1864135           490
# 25                                    Odisha          1287285           492
# 28                                 Rajasthan          1282745           321
# 10                                   Gujarat          1223806           299
# ...

# %%
#Visualization

# %%
sns.relplot(x = 'Confirmed Cases', y ='Death', hue = 'State/UT', data = data)

# %%
sns.relplot(x = 'Confirmed Cases', y ='Cured/Discharged', hue = 'State/UT', data = data)

# %%
sns.relplot(x = 'Confirmed Cases', y ='Active Cases', hue = 'State/UT', data = data)

# %%
sns.displot(data['Confirmed Cases'])

# %%
sns.displot(data['Active Cases'])

# %%
sns.displot(data['Death'])

# %%
sns.catplot(x = 'Confirmed Cases', kind = 'box', data = data)

# %%
sns.catplot(x = 'Active Cases', kind = 'box', data = data)

# %%
sns.catplot(x = 'Death', kind = 'box', data = data)
